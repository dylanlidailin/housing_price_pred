# %%
import pandas as pd

# %%
from sklearn.datasets import fetch_california_housing
housing_data = fetch_california_housing()
#print(housing_data.DESCR)

# %%
housing_data = pd.DataFrame(housing_data.data, columns=housing_data.feature_names)
